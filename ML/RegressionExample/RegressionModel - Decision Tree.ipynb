# %%
# Importing libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Loading the dataset
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# 5      31  female  25.740         0     no   3756.62160
# 6      46  female  33.440         1     no   8240.58960
# 7      37  female  27.740         3     no   7281.50560
# 8      37    male  29.830         2     no   6406.41070
# 9      60  female  25.840         0     no  28923.13692
# 10     25    male  26.220         0     no   2721.32080
# 11     62  female  26.290         0    yes  27808.72510
# 12     23    male  34.400         0     no   1826.84300
# 13     56  female  39.820         0     no  11090.71780
# 14     27    male  42.130         0    yes  39611.75770
# 15     19    male  24.600         1     no   1837.23700
# ...

# %%
datasets = pd.get_dummies(dataset, drop_first = True)

# %%
datasets
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# 5      31  25.740         0   3756.62160         0           0
# 6      46  33.440         1   8240.58960         0           0
# 7      37  27.740         3   7281.50560         0           0
# 8      37  29.830         2   6406.41070         1           0
# 9      60  25.840         0  28923.13692         0           0
# 10     25  26.220         0   2721.32080         1           0
# 11     62  26.290         0  27808.72510         0           1
# 12     23  34.400         0   1826.84300         1           0
# 13     56  39.820         0  11090.71780         0           0
# ...

# %%
# Split Independent/Input and Dependent/Output variables
indep_var = datasets[['age', 'bmi', 'children','sex_male','smoker_yes']]
dep_var = datasets[['charges']]

# %%
indep_var
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# 5      31  25.740         0         0           0
# 6      46  33.440         1         0           0
# 7      37  27.740         3         0           0
# 8      37  29.830         2         1           0
# 9      60  25.840         0         0           0
# 10     25  26.220         0         1           0
# 11     62  26.290         0         0           1
# 12     23  34.400         0         1           0
# 13     56  39.820         0         0           0
# 14     27  42.130         0         1           1
# 15     19  24.600         1         1           0
# 16     52  30.780         1         0           0
# 17     23  23.845         0         1           0
# ...

# %%
dep_var
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 5      3756.62160
# 6      8240.58960
# 7      7281.50560
# 8      6406.41070
# 9     28923.13692
# 10     2721.32080
# 11    27808.72510
# 12     1826.84300
# 13    11090.71780
# 14    39611.75770
# 15     1837.23700
# 16    10797.33620
# 17     2395.17155
# 18    10602.38500
# 19    36837.46700
# 20    13228.84695
# 21     4149.73600
# 22     1137.01100
# 23    37701.87680
# 24     6203.90175
# 25    14001.13380
# 26    14451.83515
# 27    12268.63225
# 28     2775.19215
# 29    38711.00000
# ...           ...
# 1308  33900.65300
# 1309   6875.96100
# 1310   6940.90985
# 1311   4571.41305
# 1312   4536.25900
# 1313  36397.57600
# 1314  18765.87545
# 1315  11272.33139
# 1316   1731.67700
# 1317   1163.46270
# 1318  19496.71917
# 1319   7201.70085
# 1320   5425.02335
# 1321  28101.33305
# 1322  12981.34570
# 1323  43896.37630
# 1324   4239.89265
# 1325  13143.33665
# ...

# %%
# Split data to train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(indep_var, dep_var, test_size = 1/3, random_state = 0)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(splitter='random')
regressor = regressor.fit(x_train,y_train)

# %%
y_pred = regressor.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_sq = r2_score(y_test, y_pred)

# %%
r_sq
# Out:
# 0.7384799720698685

# %%
# Save the model
import pickle

# %%
filename = 'SVMRegressionModel.sav'
pickle.dump(regressor, open(filename,'wb'))

# %%
get_model = pickle.load(open(filename,'rb'))

# %%
rd_input = float(input("R&D:"))
admin_input = float(input("Admin:"))
mark_input = float(input("Marketing: "))
fol_input = int(input("State_flo 0 or 1:"))
new_input = int(input("State_new 0 or 1:"))

# %%
result = get_model.predict([[rd_input,admin_input,mark_input,fol_input,new_input]])

# %%
result
